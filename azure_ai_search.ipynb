# %% [markdown]
# <a href="https://colab.research.google.com/github/stevansehn/python-azure-ai-search/blob/main/azure_ai_search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Install dependencies

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.7.4)

# %% [markdown]
# ## Mount drive, get API key from Drive

# %%
from google.colab import drive
import os
import requests

drive.mount('/content/drive')

with open('/content/drive/MyDrive/APIKeys/azure-ai-search.txt') as f:
    api_key = f.read().strip()

os.environ['AZURE_AI_SEARCH_API_KEY'] = api_key
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## Construct the URL for the request endpoit

# %%
search_service_name = 'my-ai-search-resource'
index_name = 'realestate-us-sample-index'
api_version = '2021-04-30-Preview'
api_key = os.getenv('AZURE_AI_SEARCH_API_KEY')

# %%
url = f"https://{search_service_name}.search.windows.net/indexes/{index_name}/docs"
headers = {
    'Content-Type': 'application/json',
    'api-key': api_key,
}

# %% [markdown]
# ## Set the query params

# %%
params = {
    'api-version': api_version,
    'search': '*'
}

# %% [markdown]
# ## Make the request

# %%
response = requests.get(url, headers=headers, params=params)

# %% [markdown]
# ## Query the entire database

# %%
if response.status_code == 200:
    results = response.json()
    for document in results['value']:
        print(document)
else:
    print(f"Error: {response.status_code}, {response.text}")
# Out:
# {'@search.score': 1.0, 'listingId': 'OTM4NjQyOQ2', 'beds': 3, 'baths': 3, 'description': 'This is a bachelor apartment and is perfect for entertaining.  This property has great views located in a culs-de-sac and features miele appliances, crown mouldings and a huge bonus room.', 'description_de': 'Dies ist eine Bachelor-Wohnung und ist perfekt für Unterhaltung.  Dieses Hotel hat eine tolle Aussicht Das Hotel liegt in einer culs-de-sac und Funktionen Miele Geräte, Krone Formteile and ein riesiger Bonus-Zimmer.', 'description_fr': 'Il s’agit d’une Garçonnière et est parfait pour se divertir.  Cette propriété a une vue imprenable situé dans un culs-de-sac et caractéristiques miele appareils, moulures and un énorme bonus de chambre.', 'description_it': 'Si tratta di un appartamento di bachelor ed è perfetto per intrattenere.  Questa proprietà ha una vista fantastica Situato in un culs-de-sac ed elettrodomestici miele caratteristiche, modanature corona and una stanza enorme bonus.', 'description_es': 'Este es un apartamento de soltero y es perfecto para el entretenimiento.  Esta propiedad tiene excelentes vistas situado en un culs-de-sac y características miele electrodomésticos, moldeados de corona and una sala adicional enorme.', 'description_pl': 'Jest to apartament licencjat i jest idealny do zabawy.  Ten obiekt oferuje wspaniale widoki na znajduje sie w culs-de-sac i funkcje urzadzen miele, sztukaterie and sale ogromny bonus.', 'description_nl': 'Dit is een Bachelor in appartement en is perfect voor entertaining.  Deze eigenschap heeft een fantastisch uitzicht gelegen in een culs-de-sac en functies miele apparaten, kroon lijstwerk and een enorme bonus-kamer.', 'sqft': 5832, 'daysOnMarket': 249, 'status': 'active', 'source': 'Lucas Roberts Homes', 'number': '451', 'street': '150th Place Northeast', 'unit': '637', 'type': 'Apartment', 'city': 'Bellevue', 'region': 'wa', 'countryCode': 'us', 'postCode': '98007', 'location': {'type': 'Point', 'coordinates': [-122.137, 47.614], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 1650456, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd3bt3apt.jpg', 'tags': ['bachelor apartment', 'entertaining', 'great views', 'culs-de-sac', 'miele appliances', 'crown mouldings', 'huge bonus room'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': ['OTM4NjQyOQ2'], 'language': 'en', 'translated_text': 'OTM4NjQyOQ2', 'masked_text': 'OTM4NjQyOQ2', 'pii_entities': []}
# {'@search.score': 1.0, 'listingId': 'OTM4NjQzMQ2', 'beds': 2, 'baths': 2, 'description': 'This is a flatlet and is freshly painted.  This home provides an acreage of land located in a dead end street and features a den, a formal dining room and a covered front porch.', 'description_de': 'Dies ist ein Allergiker und ist frisch gestrichen.  Dieses Haus bietet eine Anbaufläche von land Das Hotel liegt in einer Sackgasse und verfügt über eine Höhle, ein Esszimmer and eine überdachte Veranda.', 'description_fr': 'Il s’agit d’un appartement et est fraîchement peint.  Cette maison offre une superficie de terrain situé dans un cul-de-sac et dispose d’un boudoir, une salle à manger and une véranda couverte.', 'description_it': 'Si tratta di una casetta ed è dipinta di fresco.  Questa casa offre una superficie di terra Situato in una strada senza uscita e dispone di una tana, Sala da pranzo formale and un portico anteriore coperto.', 'description_es': 'Se trata de un flatlet y está recién pintado.  Esta casa ofrece una superficie de la tierra situado en un callejón sin salida calle y cuenta con un den, un comedor formal and un porche cubierto.', 'description_pl': 'Jest to mieszkanie i jest swiezo malowane.  Ten dom zapewnia areal ziemi polozony w slepy zaulek ulicy funkcje w den i posiadanie jadalnia and weranda przednie.', 'description_nl': 'Dit is een flatlet en vers is geschilderd.  Dit huis biedt een areaal van land gelegen in een doodlopende straat en is voorzien van een den, een formele eetkamer and een overdekte veranda.', 'sqft': 2592, 'daysOnMarket': 264, 'status': 'pending', 'source': 'Sullivan Realtors', 'number': '14836', 'street': 'Densmore Avenue North', 'unit': '140', 'type': 'Apartment', 'city': 'Shoreline', 'region': 'wa', 'countryCode': 'us', 'postCode': '98133', 'location': {'type': 'Point', 'coordinates': [-122.338, 47.7369], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 730944, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd2bt2apt.jpg', 'tags': ['flatlet', 'freshly painted', 'acreage of land', 'dead end street', 'den', 'formal dining room', 'covered front porch'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': ['OTM4NjQzMQ2'], 'language': 'en', 'translated_text': 'OTM4NjQzMQ2', 'masked_text': '***********', 'pii_entities': [{'text': 'OTM4NjQzMQ2', 'type': 'SWIFTCode', 'subtype': None, 'offset': 0, 'length': 11, 'score': 0.91}]}
# {'@search.score': 1.0, 'listingId': 'OTM4NjQzMg2', 'beds': 1, 'baths': 1, 'description': 'This is a bungalow and is a dream home.  This property has mountain views located within walking distance of a beach and features high end kitchen appliances, a garden and a huge bonus room.', 'description_de': 'Dies ist ein bungalow und ist ein Traumhaus.  Diese Eigenschaft hat Aussicht auf die Berge Das Hotel liegt nur wenige Gehminuten vom Strand und Funktionen high-End-Küchengeräte, einen Garten and ein riesiger Bonus-Zimmer.', 'description_fr': 'Il s’agit d’un bungalow et est une maison de rêve.  Cette propriété n’a vue sur la montagne Situé à proximité d’une plage et appareils de cuisine caractéristiques haut de gamme, un jardin and un énorme bonus de chambre.', 'description_it': 'Si tratta di un bungalow ed è una casa da sogno.  Questa proprietà ha la vista sulle montagne Situato a poca distanza da una spiaggia e caratteristiche high-end elettrodomestici da cucina, un giardino and una stanza enorme bonus.', 'description_es': 'Se trata de un bungalow y es una casa de ensueño.  Esta propiedad tiene vistas a la montaña situado a poca distancia de una playa y electrodomésticos de alta gama de características, un jardín and una sala adicional enorme.', 'description_pl': 'Jest to domek i jest wymarzony dom.  Ten obiekt oferuje widoki na góry polozony w odleglosci spaceru od plazy i funkcje wysokiej klasy urzadzen kuchennych, ogród and sale ogromny bonus.', 'description_nl': 'Dit is een bungalow en is een droomhuis.  Deze eigenschap heeft uitzicht op de bergen gelegen op loopafstand van het strand en functies high-end keukenapparatuur, een tuin and een enorme bonus-kamer.', 'sqft': 648, 'daysOnMarket': 258, 'status': 'active', 'source': 'Aiden Paradis Homes', 'number': '15861', 'street': 'Southeast 16th Street', 'unit': None, 'type': 'House', 'city': 'Bellevue', 'region': 'wa', 'countryCode': 'us', 'postCode': '98008', 'location': {'type': 'Point', 'coordinates': [-122.127, 47.595], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 183384, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd1bt1home.jpg', 'tags': ['bungalow', 'dream home', 'mountain views', 'walking distance of beach', 'high end kitchen appliances', 'garden', 'huge bonus room'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': ['OTM4NjQzMg2'], 'language': 'en', 'translated_text': 'OTM4NjQzMg2', 'masked_text': '***********', 'pii_entities': [{'text': 'OTM4NjQzMg2', 'type': 'SWIFTCode', 'subtype': None, 'offset': 0, 'length': 11, 'score': 0.65}]}
# {'@search.score': 1.0, 'listingId': 'OTM4NjQzMw2', 'beds': 3, 'baths': 1, 'description': 'This is a condo and is well maintained.  Enjoy water frontage located close to parks and features viking appliances, a wall of windows and a guest house.', 'description_de': 'Dies ist eine Eigentumswohnung und ist sehr gepflegt.  Genießen Sie Wasser Fassade Parks in der Nähe und Funktionen Viking Geräte, eine Wand von windows and ein Gästehaus.', 'description_fr': 'Il s’agit d’un condo et est bien entretenu.  Profitez de façade de l’eau Situé à proximité de Parcs et appareils de caractéristiques de viking, un mur de fenêtres and une maison d’hôtes.', 'description_it': "Si tratta di un condominio ed è ben tenuto.  Godere di Riva d'acqua Situato vicino ai parchi e caratteristiche elettrodomestici viking, una parete di finestre and una guest house.", 'description_es': 'Se trata de un condominio y bien mantenido.  Disfrutar de frente de agua situado cerca de parques y electrodomésticos viking de características, una pared de ventanas and una casa de huéspedes.', 'description_pl': 'Jest to domek i jest dobrze utrzymany.  Ciesz sie wody pierzei usytuowany w poblizu parków i funkcje viking urzadzen, ciana and Pensjonat.', 'description_nl': 'Dit is een condo en is goed onderhouden.  Genieten van water voorgevel vlakbij parken en functies viking apparaten, een muur van windows and een pension.', 'sqft': 1944, 'daysOnMarket': 201, 'status': 'active', 'source': 'Leduc Homes', 'number': '20505', 'street': '7th Avenue Southwest', 'unit': '497', 'type': 'Apartment', 'city': 'Normandy Park', 'region': 'wa', 'countryCode': 'us', 'postCode': '98166', 'location': {'type': 'Point', 'coordinates': [-122.345, 47.4186], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 548208, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd3bt1apt.jpg', 'tags': ['condo', 'well maintained', 'water frontage', 'parks', 'viking appliances', 'wall of windows', 'guest house'], 'people': [], 'organizations': [], 'locations': ['OTM4NjQzMw2'], 'keyphrases': ['OTM4NjQzMw2'], 'language': 'en', 'translated_text': 'OTM4NjQzMw2', 'masked_text': 'OTM4NjQzMw2', 'pii_entities': []}
# {'@search.score': 1.0, 'listingId': 'OTM4NjQ0OQ2', 'beds': 3, 'baths': 1, 'description': 'This is a bachelor apartment and is perfect for entertaining.  This home provides a large lot located in a no through road and features a lap pool, crown mouldings and a wet bar.', 'description_de': 'Dies ist eine Bachelor-Wohnung und ist perfekt für Unterhaltung.  Dieses Haus bietet eine große Menge Das Hotel liegt in einer Sackgasse und verfügt über ein Sportbecken Krone Formteile and eine wet-bar.', 'description_fr': 'Il s’agit d’une Garçonnière et est parfait pour se divertir.  Cette maison offre un grand terrain situé dans un non par route et dispose d’une piscine, moulures and un wet-bar.', 'description_it': 'Si tratta di un appartamento di bachelor ed è perfetto per intrattenere.  Questa casa offre una grande partita Situato in un no attraverso strada e dispone di una piscina a corsie, modanature corona and un wet bar.', 'description_es': 'Este es un apartamento de soltero y es perfecto para el entretenimiento.  Esta casa ofrece un amplio Lote situado en un no a través de la carretera y cuenta con una piscina, moldeados de corona and una zona de bar.', 'description_pl': 'Jest to apartament licencjat i jest idealny do zabawy.  Ten dom zawiera wiele duzych polozony w nie poprzez drogi i dysponuje basenem, sztukaterie and barek.', 'description_nl': 'Dit is een Bachelor in appartement en is perfect voor entertaining.  Dit huis biedt een grote partij gelegen in een niet door weg en beschikt over een schoot zwembad, kroon lijstwerk and een natte bar.', 'sqft': 1944, 'daysOnMarket': 297, 'status': 'active', 'source': 'Tyler Poirier Homes', 'number': '22102', 'street': '109th Place Southeast', 'unit': '105', 'type': 'Apartment', 'city': 'Kent', 'region': 'wa', 'countryCode': 'us', 'postCode': '98031', 'location': {'type': 'Point', 'coordinates': [-122.196, 47.4039], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 458784, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd3bt1apt.jpg', 'tags': ['bachelor apartment', 'entertaining', 'large lot', 'no through road', 'lap pool', 'crown mouldings', 'wet bar'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': ['OTM4NjQ0OQ2'], 'language': 'en', 'translated_text': 'OTM4NjQ0OQ2', 'masked_text': '***********', 'pii_entities': [{'text': 'OTM4NjQ0OQ2', 'type': 'SWIFTCode', 'subtype': None, 'offset': 0, 'length': 11, 'score': 0.52}]}
# {'@search.score': 1.0, 'listingId': 'OTM4NjE1MA2', 'beds': 2, 'baths': 2, 'description': 'This is a flat and is freshly painted.  This home provides a large lot located close to parks and features an attached garage, crown mouldings and two master suites.', 'description_de': 'Dies ist eine Wohnung und ist frisch gestrichen.  Dieses Haus bietet eine große Menge Parks in der Nähe und verfügt über eine angebaute Garage Krone Formteile and zwei master-Suiten.', 'description_fr': 'Il s’agit d’un appartement et est fraîchement peint.  Cette maison offre un grand terrain Situé à proximité de Parcs et dispose d’un garage attenant, moulures and deux suites master.', 'description_it': 'Si tratta di un piatto ed è dipinta di fresco.  Questa casa offre una grande partita Situato vicino ai parchi e dispone di un garage collegato, modanature corona and due master suite.', 'description_es': 'Se trata de un piso y está recién pintado.  Esta casa ofrece un amplio Lote situado cerca de parques y cuenta con un garaje adjunto, moldeados de corona and dos Masters suites.', 'description_pl': 'Jest to plaska i jest swiezo malowane.  Ten dom zawiera wiele duzych usytuowany w poblizu parków i posiada garaz, sztukaterie and dwa apartamenty.', 'description_nl': 'Dit is een flat en vers is geschilderd.  Dit huis biedt een grote partij vlakbij parken en beschikt over een aangebouwde garage, kroon lijstwerk and twee master suites.', 'sqft': 2592, 'daysOnMarket': 150, 'status': 'active', 'source': 'Mitchell Homes', 'number': '414', 'street': '145th Avenue Northeast', 'unit': '462', 'type': 'Apartment', 'city': 'Bellevue', 'region': 'wa', 'countryCode': 'us', 'postCode': '98007', 'location': {'type': 'Point', 'coordinates': [-122.147, 47.614], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 518400, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd2bt2apt.jpg', 'tags': ['flat', 'freshly painted', 'large lot', 'parks', 'attached garage', 'crown mouldings', 'two master suites'], 'people': [], 'organizations': [], 'locations': ['OTM4NjE1MA2'], 'keyphrases': [], 'language': 'sq', 'translated_text': 'OTM4NjE1MA2', 'masked_text': 'OTM4NjE1MA2', 'pii_entities': []}
# {'@search.score': 1.0, 'listingId': 'OTM4NjE2NA2', 'beds': 5, 'baths': 4, 'description': 'This is a multi-story residence and is priced to sell.  This property has ocean views located close to parks and features high end kitchen appliances, a garden and granite countertops.', 'description_de': 'Dies ist ein mehrstöckiges Wohnhaus und ist preislich um zu verkaufen.  Diese Eigenschaft hat Meerblick Parks in der Nähe und Funktionen high-End-Küchengeräte, einen Garten and Granit-Arbeitsplatten.', 'description_fr': 'Il s’agit d’une résidence de plusieurs étages un prix pour vendre.  Cette propriété offre une vue sur l’océan Situé à proximité de Parcs et appareils de cuisine caractéristiques haut de gamme, un jardin and comptoirs de granit.', 'description_it': "Si tratta di un residence di multi-storia ed è un prezzo di vendita.  Questa proprietà ha viste sull'oceano Situato vicino ai parchi e caratteristiche high-end elettrodomestici da cucina, un giardino and ripiani di granito.", 'description_es': 'Se trata de una residencia de varios pisos y tiene un precio para vender.  Esta propiedad tiene vista al mar situado cerca de parques y electrodomésticos de alta gama de características, un jardín and encimeras de granito.', 'description_pl': 'Jest to historia wielu pobytu i jest w cenie sprzedazy.  Obiekt dysponuje widokiem na ocean usytuowany w poblizu parków i funkcje wysokiej klasy urzadzen kuchennych, ogród and blaty granitowe.', 'description_nl': 'Dit is een multi verhaal residentie zijn en wordt geprijst om te verkopen.  Deze eigenschap heeft uitzicht op de Oceaan vlakbij parken en functies high-end keukenapparatuur, een tuin and countertops van het graniet.', 'sqft': 12960, 'daysOnMarket': 15, 'status': 'active', 'source': 'Zachary Rivera Realtors', 'number': '10231', 'street': 'Northeast 30th Place', 'unit': None, 'type': 'House', 'city': 'Bellevue', 'region': 'wa', 'countryCode': 'us', 'postCode': '98004', 'location': {'type': 'Point', 'coordinates': [-122.203, 47.6377], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 3045600, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd5bt4home.jpg', 'tags': ['multi-story residence', 'priced to sell', 'ocean views', 'parks', 'high end kitchen appliances', 'garden', 'granite countertops'], 'people': [], 'organizations': [], 'locations': ['OTM4NjE2NA'], 'keyphrases': [], 'language': 'sw', 'translated_text': 'OTM4NjE2NA2', 'masked_text': 'OTM4NjE2NA2', 'pii_entities': []}
# {'@search.score': 1.0, 'listingId': 'OTM4NjE2NQ2', 'beds': 1, 'baths': 1, 'description': 'This is a flatlet and is priced to sell.  This property has ocean views located close to parks and features thermador appliances, crown mouldings and a wet bar.', 'description_de': 'Dies ist ein Allergiker und ist preislich um zu verkaufen.  Diese Eigenschaft hat Meerblick Parks in der Nähe und Funktionen Thermador Geräte, Krone Formteile and eine wet-bar.', 'description_fr': 'Il s’agit d’un appartement un prix pour vendre.  Cette propriété offre une vue sur l’océan Situé à proximité de Parcs et appareils de caractéristiques de thermador, moulures and un wet-bar.', 'description_it': "Si tratta di una casetta ed è un prezzo di vendita.  Questa proprietà ha viste sull'oceano Situato vicino ai parchi e caratteristiche elettrodomestici thermador, modanature corona and un wet bar.", 'description_es': 'Se trata de un flatlet y tiene un precio para vender.  Esta propiedad tiene vista al mar situado cerca de parques y aparatos de thermador de características, moldeados de corona and una zona de bar.', 'description_pl': 'Jest to mieszkanie i jest w cenie sprzedazy.  Obiekt dysponuje widokiem na ocean usytuowany w poblizu parków i funkcje urzadzen thermador, sztukaterie and barek.', 'description_nl': 'Dit is een flatlet zijn en wordt geprijst om te verkopen.  Deze eigenschap heeft uitzicht op de Oceaan vlakbij parken en functies thermador apparaten, kroon lijstwerk and een natte bar.', 'sqft': 648, 'daysOnMarket': 120, 'status': 'pending', 'source': 'Gabriel Jones Realty', 'number': '620', 'street': 'South 25th Street', 'unit': '504', 'type': 'Apartment', 'city': 'Renton', 'region': 'wa', 'countryCode': 'us', 'postCode': '98055', 'location': {'type': 'Point', 'coordinates': [-122.209, 47.4573], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 154224, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd1bt1apt.jpg', 'tags': ['flatlet', 'priced to sell', 'ocean views', 'parks', 'thermador appliances', 'crown mouldings', 'wet bar'], 'people': [], 'organizations': [], 'locations': ['TM4Nj'], 'keyphrases': [], 'language': 'sq', 'translated_text': 'OTM4NjE2NQ2', 'masked_text': 'OTM4NjE2NQ2', 'pii_entities': []}
# {'@search.score': 1.0, 'listingId': 'OTM4NjE3Ng2', 'beds': 4, 'baths': 3, 'description': 'This is a condo and is brand new.  Enjoy gleaming hardwood floors located on a no outlet and features an attached garage, french doors throughout and a large laundry room.', 'description_de': 'Dies ist eine Eigentumswohnung und ist die Marke neu.  Genießen Sie glänzenden Holzböden Das Hotel liegt auf einem keine Steckdose und verfügt über eine angebaute Garage Französisch Türen im gesamten and eine große Waschküche.', 'description_fr': 'Il s’agit d’un condo et est la marque nouvelle.  Profitez de parquet brillant Situé sur une aucune prise et dispose d’un garage attenant, français les portes tout au long de and une grande buanderie.', 'description_it': 'Si tratta di un condominio ed è il marchio nuovo.  Godere di luccicanti pavimenti Situato su una non presa e dispone di un garage collegato, porte-finestre in tutto and una grande sala lavanderia.', 'description_es': 'Se trata de un condominio y es marca nueva.  Disfrutar relucientes pisos de madera situado en una sin salida y cuenta con un garaje adjunto, francés puertas a lo largo de and un amplio lavadero.', 'description_pl': 'Jest to domek i to nowa marka.  Ciesz sie lsniace drewniane podlogi znajduje sie na nie gniazda i posiada garaz, Francuskie drzwi calym and duzy pralnia.', 'description_nl': 'Dit is een condo en is het merk nieuwe.  Geniet van de glanzende hardhoutvloeren gelegen op een geen stopcontact en beschikt over een aangebouwde garage, tuindeuren in de gehele and een grote wasruimte.', 'sqft': 7776, 'daysOnMarket': 207, 'status': 'active', 'source': 'Houle Homes', 'number': '11514', 'street': 'Southeast 221st Place', 'unit': '532', 'type': 'Apartment', 'city': 'Kent', 'region': 'wa', 'countryCode': 'us', 'postCode': '98031', 'location': {'type': 'Point', 'coordinates': [-122.188, 47.4039], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 1555200, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd4bt3apt.jpg', 'tags': ['condo', 'brand new', 'hardwood floors', 'no outlet', 'attached garage', 'french doors throughout', 'large laundry room'], 'people': [], 'organizations': [], 'locations': ['4Nj'], 'keyphrases': [], 'language': 'sq', 'translated_text': 'OTM4NjE3Ng2', 'masked_text': 'OTM4NjE3Ng2', 'pii_entities': []}
# {'@search.score': 1.0, 'listingId': 'OTM4NjE4Nw2', 'beds': 1, 'baths': 1, 'description': 'This is a flatlet and is perfect for entertaining.  Enjoy gleaming hardwood floors located in a culs-de-sac and features a heated pool, beautiful bedroom floors and a huge bonus room.', 'description_de': 'Dies ist ein Allergiker und ist perfekt für Unterhaltung.  Genießen Sie glänzenden Holzböden Das Hotel liegt in einer culs-de-sac und verfügt über einen beheizten Swimmingpool, schöne Zimmer-Etagen and ein riesiger Bonus-Zimmer.', 'description_fr': 'Il s’agit d’un appartement et est parfait pour se divertir.  Profitez de parquet brillant situé dans un culs-de-sac et dispose d’une piscine chauffée, planchers de belle chambre and un énorme bonus de chambre.', 'description_it': 'Si tratta di una casetta ed è perfetto per intrattenere.  Godere di luccicanti pavimenti Situato in un culs-de-sac e vanta una piscina riscaldata, piani di bella camera da letto and una stanza enorme bonus.', 'description_es': 'Se trata de un flatlet y es perfecto para el entretenimiento.  Disfrutar relucientes pisos de madera situado en un culs-de-sac y cuenta con una piscina climatizada, pisos de dormitorio hermoso and una sala adicional enorme.', 'description_pl': 'Jest to mieszkanie i jest idealny do zabawy.  Ciesz sie lsniace drewniane podlogi znajduje sie w culs-de-sac i dysponuje basenem z podgrzewana woda, piekna sypialnia podlogi and sale ogromny bonus.', 'description_nl': 'Dit is een flatlet en is perfect voor entertaining.  Geniet van de glanzende hardhoutvloeren gelegen in een culs-de-sac en beschikt over een verwarmd zwembad, mooie slaapkamer vloeren and een enorme bonus-kamer.', 'sqft': 648, 'daysOnMarket': 174, 'status': 'active', 'source': 'Simard Homes', 'number': '1955', 'street': '156th Avenue Northeast', 'unit': '567', 'type': 'Apartment', 'city': 'Bellevue', 'region': 'wa', 'countryCode': 'us', 'postCode': '98007', 'location': {'type': 'Point', 'coordinates': [-122.133, 47.6275], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 187272, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd1bt1apt.jpg', 'tags': ['flatlet', 'entertaining', 'hardwood floors', 'culs-de-sac', 'heated pool', 'beautiful bedroom floors', 'huge bonus room'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': ['OTM4NjE4Nw2'], 'language': 'en', 'translated_text': 'OTM4NjE4Nw2', 'masked_text': '***********', 'pii_entities': [{'text': 'OTM4NjE4Nw2', 'type': 'SWIFTCode', 'subtype': None, 'offset': 0, 'length': 11, 'score': 0.9}]}
# {'@search.score': 1.0, 'listingId': 'OTM4NjE5Mw2', 'beds': 3, 'baths': 3, 'description': 'This is a flatlet and is a beautiful home.  This home provides an acreage of land located in a no through road and features a den, a generous backyard and two master suites.', 'description_de': 'Dies ist ein Allergiker und ist ein schönes Zuhause.  Dieses Haus bietet eine Anbaufläche von land Das Hotel liegt in einer Sackgasse und verfügt über eine Höhle, ein großzügiger Garten and zwei master-Suiten.', 'description_fr': 'Il s’agit d’un appartement et est une belle maison.  Cette maison offre une superficie de terrain situé dans un non par route et dispose d’un boudoir, un jardin généreux and deux suites master.', 'description_it': 'Si tratta di una casetta è una bellissima casa.  Questa casa offre una superficie di terra Situato in un no attraverso strada e dispone di una tana, un generoso cortile and due master suite.', 'description_es': 'Se trata de un flatlet y es una hermosa casa.  Esta casa ofrece una superficie de la tierra situado en un no a través de la carretera y cuenta con un den, un generoso patio trasero and dos Masters suites.', 'description_pl': 'Jest to mieszkanie i jest piekny dom.  Ten dom zapewnia areal ziemi polozony w nie poprzez drogi funkcje w den i hojny podwórku and dwa apartamenty.', 'description_nl': 'Dit is een flatlet en is een mooi huis.  Dit huis biedt een areaal van land gelegen in een niet door weg en is voorzien van een den, een royale achtertuin and twee master suites.', 'sqft': 5832, 'daysOnMarket': 240, 'status': 'active', 'source': 'Tyler Boivin Realty', 'number': '21658', 'street': 'Southeast 239th Place', 'unit': '63', 'type': 'Apartment', 'city': 'Maple Valley', 'region': 'wa', 'countryCode': 'us', 'postCode': '98038', 'location': {'type': 'Point', 'coordinates': [-122.051, 47.3875], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 1189728, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd3bt3apt.jpg', 'tags': ['flatlet', 'beautiful home', 'acreage of land', 'no through road', 'den', 'generous backyard', 'two master suites'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': [], 'language': 'sq', 'translated_text': 'OTM4NjE5Mw2', 'masked_text': 'OTM4NjE5Mw2', 'pii_entities': []}
# {'@search.score': 1.0, 'listingId': 'OTM4NjM1MQ2', 'beds': 2, 'baths': 2, 'description': 'This is a semi-detached house and is a short sale.  This property has mountain views located on a no outlet and features an attached garage, a formal dining room and a covered front porch.', 'description_de': 'Dies ist eine Doppelhaushälfte und ist ein Leerverkauf.  Diese Eigenschaft hat Aussicht auf die Berge Das Hotel liegt auf einem keine Steckdose und verfügt über eine angebaute Garage ein Esszimmer and eine überdachte Veranda.', 'description_fr': 'Il s’agit d’une maison jumelée et une vente à découvert.  Cette propriété n’a vue sur la montagne Situé sur une aucune prise et dispose d’un garage attenant, une salle à manger and une véranda couverte.', 'description_it': 'Si tratta di una casa bifamiliare è una vendita a breve.  Questa proprietà ha la vista sulle montagne Situato su una non presa e dispone di un garage collegato, Sala da pranzo formale and un portico anteriore coperto.', 'description_es': 'Esta es una casa adosada y es una venta corta.  Esta propiedad tiene vistas a la montaña situado en una sin salida y cuenta con un garaje adjunto, un comedor formal and un porche cubierto.', 'description_pl': 'Jest to dom-blizniak i krótkiej sprzedazy.  Ten obiekt oferuje widoki na góry znajduje sie na nie gniazda i posiada garaz, posiadanie jadalnia and weranda przednie.', 'description_nl': 'Dit is een semi-vrijstaande woning en is een korte verkoop.  Deze eigenschap heeft uitzicht op de bergen gelegen op een geen stopcontact en beschikt over een aangebouwde garage, een formele eetkamer and een overdekte veranda.', 'sqft': 2592, 'daysOnMarket': 291, 'status': 'sold', 'source': 'Myers Homes', 'number': '27337', 'street': '245th Avenue Southeast', 'unit': None, 'type': 'House', 'city': 'Maple Valley', 'region': 'wa', 'countryCode': 'us', 'postCode': '98038', 'location': {'type': 'Point', 'coordinates': [-122.016, 47.357], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 624672, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd2bt2home.jpg', 'tags': ['semi-detached house', 'short sale', 'mountain views', 'no outlet', 'attached garage', 'formal dining room', 'covered front porch'], 'people': [], 'organizations': [], 'locations': ['OTM4NjM1MQ2'], 'keyphrases': ['OTM4NjM1MQ2'], 'language': 'it', 'translated_text': 'OTM4NjM1MQ2', 'masked_text': '***********', 'pii_entities': [{'text': 'OTM4NjM1MQ2', 'type': 'SWIFTCode', 'subtype': None, 'offset': 0, 'length': 11, 'score': 1.0}]}
# {'@search.score': 1.0, 'listingId': 'OTM4NjM1Ng2', 'beds': 4, 'baths': 3, 'description': 'This is a bachelor apartment and is perfect for entertaining.  This property has great views located in a cul-de-sac and features viking appliances, beautiful bedroom floors and two master suites.', 'description_de': 'Dies ist eine Bachelor-Wohnung und ist perfekt für Unterhaltung.  Dieses Hotel hat eine tolle Aussicht gelegen in einer Sackgasse und Funktionen Viking Geräte, schöne Zimmer-Etagen and zwei master-Suiten.', 'description_fr': 'Il s’agit d’une Garçonnière et est parfait pour se divertir.  Cette propriété a une vue imprenable situé dans une impasse et appareils de caractéristiques de viking, planchers de belle chambre and deux suites master.', 'description_it': 'Si tratta di un appartamento di bachelor ed è perfetto per intrattenere.  Questa proprietà ha una vista fantastica Situato in una strada senza uscita e caratteristiche elettrodomestici viking, piani di bella camera da letto and due master suite.', 'description_es': 'Este es un apartamento de soltero y es perfecto para el entretenimiento.  Esta propiedad tiene excelentes vistas situado en un callejón sin salida y electrodomésticos viking de características, pisos de dormitorio hermoso and dos Masters suites.', 'description_pl': 'Jest to apartament licencjat i jest idealny do zabawy.  Ten obiekt oferuje wspaniale widoki na polozony w zaulku i funkcje viking urzadzen, piekna sypialnia podlogi and dwa apartamenty.', 'description_nl': 'Dit is een Bachelor in appartement en is perfect voor entertaining.  Deze eigenschap heeft een fantastisch uitzicht gelegen in een doodlopende straat en functies viking apparaten, mooie slaapkamer vloeren and twee master suites.', 'sqft': 7776, 'daysOnMarket': 90, 'status': 'sold', 'source': 'Aiden Harris Realtors', 'number': '16317', 'street': 'Southeast 40th Street', 'unit': '413', 'type': 'Apartment', 'city': 'Bellevue', 'region': 'wa', 'countryCode': 'us', 'postCode': '98006', 'location': {'type': 'Point', 'coordinates': [-122.124, 47.5738], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 1780704, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd4bt3apt.jpg', 'tags': ['bachelor apartment', 'entertaining', 'great views', 'cul-de-sac', 'viking appliances', 'beautiful bedroom floors', 'two master suites'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': ['OTM4NjM1Ng2'], 'language': 'en', 'translated_text': 'OTM4NjM1Ng2', 'masked_text': '***********', 'pii_entities': [{'text': 'OTM4NjM1Ng2', 'type': 'SWIFTCode', 'subtype': None, 'offset': 0, 'length': 11, 'score': 0.99}]}
# {'@search.score': 1.0, 'listingId': 'OTM4NjM5Ng2', 'beds': 1, 'baths': 1, 'description': 'This is a flat and is a beautiful home.  Enjoy water frontage located in a cultisac and features a home office, a wall of windows and a guest house.', 'description_de': 'Dies ist eine Wohnung und ist ein schönes Zuhause.  Genießen Sie Wasser Fassade Das Hotel liegt in einer cultisac und verfügt über ein home-Office eine Wand von windows and ein Gästehaus.', 'description_fr': 'Il s’agit d’un appartement et est une belle maison.  Profitez de façade de l’eau situé dans un cultisac et dispose d’un bureau à domicile, un mur de fenêtres and une maison d’hôtes.', 'description_it': "Si tratta di un piatto è una bellissima casa.  Godere di Riva d'acqua Situato in un cultisac e dispone di un ufficio a casa, una parete di finestre and una guest house.", 'description_es': 'Se trata de un piso y es una hermosa casa.  Disfrutar de frente de agua situado en un cultisac y cuenta con una oficina en casa, una pared de ventanas and una casa de huéspedes.', 'description_pl': 'Jest to plaska i jest piekny dom.  Ciesz sie wody pierzei znajduje sie w cultisac i posiada biuro w domu, ciana and Pensjonat.', 'description_nl': 'Dit is een flat en is een mooi huis.  Genieten van water voorgevel gelegen in een cultisac en beschikt over een kantoor aan huis, een muur van windows and een pension.', 'sqft': 648, 'daysOnMarket': 252, 'status': 'active', 'source': 'Ryan Taylor Homes', 'number': '5626', 'street': 'Southeast 2nd Court', 'unit': '84', 'type': 'Apartment', 'city': 'Renton', 'region': 'wa', 'countryCode': 'us', 'postCode': '98059', 'location': {'type': 'Point', 'coordinates': [-122.143, 47.4819], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 141264, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd1bt1apt.jpg', 'tags': ['flat', 'beautiful home', 'water frontage', 'cultisac', 'home office', 'wall of windows', 'guest house'], 'people': [], 'organizations': [], 'locations': ['OTM4NjM5Ng2'], 'keyphrases': ['OTM4NjM5Ng2'], 'language': 'en', 'translated_text': 'OTM4NjM5Ng2', 'masked_text': '***********', 'pii_entities': [{'text': 'OTM4NjM5Ng2', 'type': 'SWIFTCode', 'subtype': None, 'offset': 0, 'length': 11, 'score': 0.99}]}
# {'@search.score': 1.0, 'listingId': 'OTM4NjUyMg2', 'beds': 4, 'baths': 3, 'description': 'This is a semi-detached house and is brand new.  This property has mountain views located in a cul-de-sac and features a home office, a garden and a covered front porch.', 'description_de': 'Dies ist eine Doppelhaushälfte und ist die Marke neu.  Diese Eigenschaft hat Aussicht auf die Berge gelegen in einer Sackgasse und verfügt über ein home-Office einen Garten and eine überdachte Veranda.', 'description_fr': 'Il s’agit d’une maison jumelée et est la marque nouvelle.  Cette propriété n’a vue sur la montagne situé dans une impasse et dispose d’un bureau à domicile, un jardin and une véranda couverte.', 'description_it': 'Si tratta di una casa bifamiliare ed è il marchio nuovo.  Questa proprietà ha la vista sulle montagne Situato in una strada senza uscita e dispone di un ufficio a casa, un giardino and un portico anteriore coperto.', 'description_es': 'Esta es una casa adosada y es marca nueva.  Esta propiedad tiene vistas a la montaña situado en un callejón sin salida y cuenta con una oficina en casa, un jardín and un porche cubierto.', 'description_pl': 'Jest to dom-blizniak i to nowa marka.  Ten obiekt oferuje widoki na góry polozony w zaulku i posiada biuro w domu, ogród and weranda przednie.', 'description_nl': 'Dit is een semi-vrijstaande woning en is het merk nieuwe.  Deze eigenschap heeft uitzicht op de bergen gelegen in een doodlopende straat en beschikt over een kantoor aan huis, een tuin and een overdekte veranda.', 'sqft': 7776, 'daysOnMarket': 204, 'status': 'pending', 'source': 'Eric Sanchez Realtors', 'number': '17434', 'street': '145th Place Northeast', 'unit': None, 'type': 'House', 'city': 'Woodinville', 'region': 'wa', 'countryCode': 'us', 'postCode': '98072', 'location': {'type': 'Point', 'coordinates': [-122.146, 47.7548], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 1796256, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd4bt3home.jpg', 'tags': ['semi-detached house', 'brand new', 'mountain views', 'cul-de-sac', 'home office', 'garden', 'covered front porch'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': ['OTM4NjUyMg2'], 'language': 'en', 'translated_text': 'OTM4NjUyMg2', 'masked_text': '***********', 'pii_entities': [{'text': 'OTM4NjUyMg2', 'type': 'SWIFTCode', 'subtype': None, 'offset': 0, 'length': 11, 'score': 0.98}]}
# {'@search.score': 1.0, 'listingId': 'OTM4NjUzMQ2', 'beds': 4, 'baths': 2, 'description': 'This is a flatlet and is a great starter home.  This home provides an acreage of land located in a dead end street and features miele appliances, french doors throughout and vaulted ceilings.', 'description_de': 'Dies ist ein Allergiker und ist ein guter Einstieg nach Hause.  Dieses Haus bietet eine Anbaufläche von land Das Hotel liegt in einer Sackgasse und Funktionen Miele Geräte, Französisch Türen im gesamten and Gewölbedecken.', 'description_fr': 'Il s’agit d’un appartement et est une grande première maison.  Cette maison offre une superficie de terrain situé dans un cul-de-sac et caractéristiques miele appareils, français les portes tout au long de and plafonds voûtés.', 'description_it': 'Si tratta di una casetta è una grande casa di avviamento.  Questa casa offre una superficie di terra Situato in una strada senza uscita ed elettrodomestici miele caratteristiche, porte-finestre in tutto and soffitti a volta.', 'description_es': 'Se trata de un flatlet y es un gran motor de arranque casa.  Esta casa ofrece una superficie de la tierra situado en un callejón sin salida calle y características miele electrodomésticos, francés puertas a lo largo de and techos abovedados.', 'description_pl': 'Jest to mieszkanie i jest wielkim starter do domu.  Ten dom zapewnia areal ziemi polozony w slepy zaulek ulicy i funkcje urzadzen miele, Francuskie drzwi calym and sklepienie.', 'description_nl': 'Dit is een flatlet en is een groot voorgerecht thuis.  Dit huis biedt een areaal van land gelegen in een doodlopende straat en functies miele apparaten, tuindeuren in de gehele and gewelfde plafonds.', 'sqft': 5184, 'daysOnMarket': 0, 'status': 'pending', 'source': 'Jonathan Bergeron Realtors', 'number': '205', 'street': '164th Avenue Northeast', 'unit': '539', 'type': 'Apartment', 'city': 'Bellevue', 'region': 'wa', 'countryCode': 'us', 'postCode': '98008', 'location': {'type': 'Point', 'coordinates': [-122.122, 47.612], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 1078272, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd4bt2apt.jpg', 'tags': ['flatlet', 'great starter home', 'acreage of land', 'dead end street', 'miele appliances', 'french doors throughout', 'vaulted ceilings'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': ['OTM4NjUzMQ2'], 'language': 'en', 'translated_text': 'OTM4NjUzMQ2', 'masked_text': '***********', 'pii_entities': [{'text': 'OTM4NjUzMQ2', 'type': 'SWIFTCode', 'subtype': None, 'offset': 0, 'length': 11, 'score': 1.0}]}
# {'@search.score': 1.0, 'listingId': 'OTM4NjU0Mg2', 'beds': 4, 'baths': 3, 'description': 'This is a condominium and is priced to sell.  Enjoy water frontage located in a no through road and features an office, a generous backyard and a covered front porch.', 'description_de': 'Dies ist eine Eigentumswohnung und ist preislich um zu verkaufen.  Genießen Sie Wasser Fassade Das Hotel liegt in einer Sackgasse und ist mit einem Büro, ein großzügiger Garten and eine überdachte Veranda.', 'description_fr': 'Il s’agit d’un immeuble en copropriété un prix pour vendre.  Profitez de façade de l’eau situé dans un non par route et un bureau, un jardin généreux and une véranda couverte.', 'description_it': "Si tratta di un condominio ed è un prezzo di vendita.  Godere di Riva d'acqua Situato in un no attraverso strada e dispone di un ufficio, un generoso cortile and un portico anteriore coperto.", 'description_es': 'Se trata de un condominio y tiene un precio para vender.  Disfrutar de frente de agua situado en un no a través de la carretera y características de una oficina, un generoso patio trasero and un porche cubierto.', 'description_pl': 'Jest to kondominium i jest w cenie sprzedazy.  Ciesz sie wody pierzei polozony w nie poprzez drogi i funkcje Biuro, hojny podwórku and weranda przednie.', 'description_nl': 'Dit is een condominium zijn en wordt geprijst om te verkopen.  Genieten van water voorgevel gelegen in een niet door weg en beschikt over een bureau, een royale achtertuin and een overdekte veranda.', 'sqft': 7776, 'daysOnMarket': 90, 'status': 'active', 'source': 'Robinson Realty', 'number': '12339', 'street': 'Southeast 23rd Place', 'unit': '42', 'type': 'Apartment', 'city': 'Bellevue', 'region': 'wa', 'countryCode': 'us', 'postCode': '98005', 'location': {'type': 'Point', 'coordinates': [-122.172, 47.5894], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 2107296, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd4bt3apt.jpg', 'tags': ['condominium', 'priced to sell', 'water frontage', 'no through road', 'office', 'generous backyard', 'covered front porch'], 'people': [], 'organizations': [], 'locations': ['OTM4Nj', '0Mg'], 'keyphrases': [], 'language': 'hr', 'translated_text': 'OTM4NJU0Mg2', 'masked_text': 'OTM4NjU0Mg2', 'pii_entities': []}
# {'@search.score': 1.0, 'listingId': 'OTM4NjI3NA2', 'beds': 2, 'baths': 2, 'description': 'This is a condo and is perfect for entertaining.  This home provides an acreage of land located within walking distance of a beach and features a den, a garden and a large walk in closet.', 'description_de': 'Dies ist eine Eigentumswohnung und ist perfekt für Unterhaltung.  Dieses Haus bietet eine Anbaufläche von land Das Hotel liegt nur wenige Gehminuten vom Strand und verfügt über eine Höhle, einen Garten and einen großen begehbaren Kleiderschrank.', 'description_fr': 'Il s’agit d’un condo et est parfait pour se divertir.  Cette maison offre une superficie de terrain Situé à proximité d’une plage et dispose d’un boudoir, un jardin and une grande promenade dans le placard.', 'description_it': 'Si tratta di un condominio ed è perfetto per intrattenere.  Questa casa offre una superficie di terra Situato a poca distanza da una spiaggia e dispone di una tana, un giardino and una grande cabina armadio.', 'description_es': 'Se trata de un condominio y es perfecto para el entretenimiento.  Esta casa ofrece una superficie de la tierra situado a poca distancia de una playa y cuenta con un den, un jardín and un gran paseo en el armario.', 'description_pl': 'Jest to domek i jest idealny do zabawy.  Ten dom zapewnia areal ziemi polozony w odleglosci spaceru od plazy funkcje w den i ogród and duzych odleglosci w szafie.', 'description_nl': 'Dit is een condo en is perfect voor entertaining.  Dit huis biedt een areaal van land gelegen op loopafstand van het strand en is voorzien van een den, een tuin and een grote inloopkast.', 'sqft': 2592, 'daysOnMarket': 78, 'status': 'pending', 'source': 'Jason Cote Homes', 'number': '404', 'street': 'Bangert Place', 'unit': '126', 'type': 'Apartment', 'city': 'Enumclaw', 'region': 'wa', 'countryCode': 'us', 'postCode': '98022', 'location': {'type': 'Point', 'coordinates': [-121.986, 47.1948], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 717984, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd2bt2apt.jpg', 'tags': ['condo', 'entertaining', 'acreage of land', 'walking distance of beach', 'den', 'garden', 'large walk in closet'], 'people': [], 'organizations': [], 'locations': ['OTM4NjI3NA2'], 'keyphrases': [], 'language': 'sq', 'translated_text': 'OTM4NjI3NA2', 'masked_text': 'OTM4NjI3NA2', 'pii_entities': []}
# {'@search.score': 1.0, 'listingId': 'OTM4NjI4OA2', 'beds': 3, 'baths': 3, 'description': 'This is a multi-story residence and is a beautiful home.  Enjoy water frontage located close to schools and features a lap pool, a generous backyard and two master suites.', 'description_de': 'Dies ist ein mehrstöckiges Wohnhaus und ist ein schönes Zuhause.  Genießen Sie Wasser Fassade Das Hotel liegt in der Nähe von Schulen und verfügt über ein Sportbecken ein großzügiger Garten and zwei master-Suiten.', 'description_fr': 'Il s’agit d’une résidence de plusieurs étages et est une belle maison.  Profitez de façade de l’eau Situé à proximité des écoles et dispose d’une piscine, un jardin généreux and deux suites master.', 'description_it': "Si tratta di un residence di multi-storia è una bellissima casa.  Godere di Riva d'acqua Situato vicino alle scuole e dispone di una piscina a corsie, un generoso cortile and due master suite.", 'description_es': 'Se trata de una residencia de varios pisos y es una hermosa casa.  Disfrutar de frente de agua situado cerca de colegios y cuenta con una piscina, un generoso patio trasero and dos Masters suites.', 'description_pl': 'Jest to historia wielu pobytu i jest piekny dom.  Ciesz sie wody pierzei polozony w poblizu szkoly i dysponuje basenem, hojny podwórku and dwa apartamenty.', 'description_nl': 'Dit is een multi verhaal residentie en is een mooi huis.  Genieten van water voorgevel vlakbij scholen en beschikt over een schoot zwembad, een royale achtertuin and twee master suites.', 'sqft': 5832, 'daysOnMarket': 102, 'status': 'active', 'source': 'Berube Realty', 'number': '15005', 'street': '37th Avenue Northeast', 'unit': None, 'type': 'House', 'city': 'Lake Forest Park', 'region': 'wa', 'countryCode': 'us', 'postCode': '98155', 'location': {'type': 'Point', 'coordinates': [-122.289, 47.7372], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 1178064, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd3bt3home.jpg', 'tags': ['multi-story residence', 'beautiful home', 'water frontage', 'schools', 'lap pool', 'generous backyard', 'two master suites'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': ['OTM4NjI4OA2'], 'language': 'en', 'translated_text': 'OTM4NjI4OA2', 'masked_text': '***********', 'pii_entities': [{'text': 'OTM4NjI4OA2', 'type': 'SWIFTCode', 'subtype': None, 'offset': 0, 'length': 11, 'score': 0.99}]}
# {'@search.score': 1.0, 'listingId': 'OTM4NjIwNg2', 'beds': 3, 'baths': 3, 'description': 'This is a semi-detached house and is a dream home.  Enjoy lake front property located close to shopping and features a den, wood floors and a guest room.', 'description_de': 'Dies ist eine Doppelhaushälfte und ist ein Traumhaus.  Genießen Sie See Immobilien Das Hotel liegt nahe an den Geschäften und verfügt über eine Höhle, Holzböden and ein Gästezimmer.', 'description_fr': 'Il s’agit d’une maison jumelée et est une maison de rêve.  Profitez de cette propriété front de lac Situé à proximité des commerces et dispose d’un boudoir, planchers de bois and une chambre d’hôtes.', 'description_it': 'Si tratta di una casa bifamiliare ed è una casa da sogno.  Godere di proprietà fronte lago Situato vicino a negozi e dispone di una tana, pavimenti in legno and Camera per gli ospiti.', 'description_es': 'Esta es una casa adosada y es una casa de ensueño.  Disfrute de propiedad frente lago situado cerca de tiendas y cuenta con un den, pisos de madera and una habitación de huéspedes.', 'description_pl': 'Jest to dom-blizniak i jest wymarzony dom.  Ciesz sie lake front Wlasciwosc polozony w poblizu zakupy funkcje w den i podlogi drewniane and Pokój goscinny.', 'description_nl': 'Dit is een semi-vrijstaande woning en is een droomhuis.  Geniet van lake eigendom vlakbij winkels en is voorzien van een den, houten vloeren and een kamer.', 'sqft': 5832, 'daysOnMarket': 111, 'status': 'active', 'source': 'Angel Morris Realtors', 'number': '23953', 'street': '58th Court South', 'unit': None, 'type': 'House', 'city': 'Kent', 'region': 'wa', 'countryCode': 'us', 'postCode': '98032', 'location': {'type': 'Point', 'coordinates': [-122.261, 47.3874], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 1533816, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd3bt3home.jpg', 'tags': ['semi-detached house', 'dream home', 'lake front property', 'shopping', 'den', 'wood floors', 'guest room'], 'people': [], 'organizations': [], 'locations': ['OTM4NjIwNg2'], 'keyphrases': ['OTM4NjIwNg2'], 'language': 'en', 'translated_text': 'OTM4NjIwNg2', 'masked_text': '***********', 'pii_entities': [{'text': 'OTM4NjIwNg2', 'type': 'SWIFTCode', 'subtype': None, 'offset': 0, 'length': 11, 'score': 0.99}]}

# %% [markdown]
# ## Query only the first 5 entries

# %%
params = {
    'api-version': api_version,
    '$top': 5
}
response = requests.get(url, headers=headers, params=params)
if response.status_code == 200:
    results = response.json()
    for document in results['value']:
        print(document)
else:
    print(f"Error: {response.status_code}, {response.text}")
# Out:
# {'@search.score': 1.0, 'listingId': 'OTM4NjQyOQ2', 'beds': 3, 'baths': 3, 'description': 'This is a bachelor apartment and is perfect for entertaining.  This property has great views located in a culs-de-sac and features miele appliances, crown mouldings and a huge bonus room.', 'description_de': 'Dies ist eine Bachelor-Wohnung und ist perfekt für Unterhaltung.  Dieses Hotel hat eine tolle Aussicht Das Hotel liegt in einer culs-de-sac und Funktionen Miele Geräte, Krone Formteile and ein riesiger Bonus-Zimmer.', 'description_fr': 'Il s’agit d’une Garçonnière et est parfait pour se divertir.  Cette propriété a une vue imprenable situé dans un culs-de-sac et caractéristiques miele appareils, moulures and un énorme bonus de chambre.', 'description_it': 'Si tratta di un appartamento di bachelor ed è perfetto per intrattenere.  Questa proprietà ha una vista fantastica Situato in un culs-de-sac ed elettrodomestici miele caratteristiche, modanature corona and una stanza enorme bonus.', 'description_es': 'Este es un apartamento de soltero y es perfecto para el entretenimiento.  Esta propiedad tiene excelentes vistas situado en un culs-de-sac y características miele electrodomésticos, moldeados de corona and una sala adicional enorme.', 'description_pl': 'Jest to apartament licencjat i jest idealny do zabawy.  Ten obiekt oferuje wspaniale widoki na znajduje sie w culs-de-sac i funkcje urzadzen miele, sztukaterie and sale ogromny bonus.', 'description_nl': 'Dit is een Bachelor in appartement en is perfect voor entertaining.  Deze eigenschap heeft een fantastisch uitzicht gelegen in een culs-de-sac en functies miele apparaten, kroon lijstwerk and een enorme bonus-kamer.', 'sqft': 5832, 'daysOnMarket': 249, 'status': 'active', 'source': 'Lucas Roberts Homes', 'number': '451', 'street': '150th Place Northeast', 'unit': '637', 'type': 'Apartment', 'city': 'Bellevue', 'region': 'wa', 'countryCode': 'us', 'postCode': '98007', 'location': {'type': 'Point', 'coordinates': [-122.137, 47.614], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 1650456, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd3bt3apt.jpg', 'tags': ['bachelor apartment', 'entertaining', 'great views', 'culs-de-sac', 'miele appliances', 'crown mouldings', 'huge bonus room'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': ['OTM4NjQyOQ2'], 'language': 'en', 'translated_text': 'OTM4NjQyOQ2', 'masked_text': 'OTM4NjQyOQ2', 'pii_entities': []}
# {'@search.score': 1.0, 'listingId': 'OTM4NjQzMQ2', 'beds': 2, 'baths': 2, 'description': 'This is a flatlet and is freshly painted.  This home provides an acreage of land located in a dead end street and features a den, a formal dining room and a covered front porch.', 'description_de': 'Dies ist ein Allergiker und ist frisch gestrichen.  Dieses Haus bietet eine Anbaufläche von land Das Hotel liegt in einer Sackgasse und verfügt über eine Höhle, ein Esszimmer and eine überdachte Veranda.', 'description_fr': 'Il s’agit d’un appartement et est fraîchement peint.  Cette maison offre une superficie de terrain situé dans un cul-de-sac et dispose d’un boudoir, une salle à manger and une véranda couverte.', 'description_it': 'Si tratta di una casetta ed è dipinta di fresco.  Questa casa offre una superficie di terra Situato in una strada senza uscita e dispone di una tana, Sala da pranzo formale and un portico anteriore coperto.', 'description_es': 'Se trata de un flatlet y está recién pintado.  Esta casa ofrece una superficie de la tierra situado en un callejón sin salida calle y cuenta con un den, un comedor formal and un porche cubierto.', 'description_pl': 'Jest to mieszkanie i jest swiezo malowane.  Ten dom zapewnia areal ziemi polozony w slepy zaulek ulicy funkcje w den i posiadanie jadalnia and weranda przednie.', 'description_nl': 'Dit is een flatlet en vers is geschilderd.  Dit huis biedt een areaal van land gelegen in een doodlopende straat en is voorzien van een den, een formele eetkamer and een overdekte veranda.', 'sqft': 2592, 'daysOnMarket': 264, 'status': 'pending', 'source': 'Sullivan Realtors', 'number': '14836', 'street': 'Densmore Avenue North', 'unit': '140', 'type': 'Apartment', 'city': 'Shoreline', 'region': 'wa', 'countryCode': 'us', 'postCode': '98133', 'location': {'type': 'Point', 'coordinates': [-122.338, 47.7369], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 730944, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd2bt2apt.jpg', 'tags': ['flatlet', 'freshly painted', 'acreage of land', 'dead end street', 'den', 'formal dining room', 'covered front porch'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': ['OTM4NjQzMQ2'], 'language': 'en', 'translated_text': 'OTM4NjQzMQ2', 'masked_text': '***********', 'pii_entities': [{'text': 'OTM4NjQzMQ2', 'type': 'SWIFTCode', 'subtype': None, 'offset': 0, 'length': 11, 'score': 0.91}]}
# {'@search.score': 1.0, 'listingId': 'OTM4NjQzMg2', 'beds': 1, 'baths': 1, 'description': 'This is a bungalow and is a dream home.  This property has mountain views located within walking distance of a beach and features high end kitchen appliances, a garden and a huge bonus room.', 'description_de': 'Dies ist ein bungalow und ist ein Traumhaus.  Diese Eigenschaft hat Aussicht auf die Berge Das Hotel liegt nur wenige Gehminuten vom Strand und Funktionen high-End-Küchengeräte, einen Garten and ein riesiger Bonus-Zimmer.', 'description_fr': 'Il s’agit d’un bungalow et est une maison de rêve.  Cette propriété n’a vue sur la montagne Situé à proximité d’une plage et appareils de cuisine caractéristiques haut de gamme, un jardin and un énorme bonus de chambre.', 'description_it': 'Si tratta di un bungalow ed è una casa da sogno.  Questa proprietà ha la vista sulle montagne Situato a poca distanza da una spiaggia e caratteristiche high-end elettrodomestici da cucina, un giardino and una stanza enorme bonus.', 'description_es': 'Se trata de un bungalow y es una casa de ensueño.  Esta propiedad tiene vistas a la montaña situado a poca distancia de una playa y electrodomésticos de alta gama de características, un jardín and una sala adicional enorme.', 'description_pl': 'Jest to domek i jest wymarzony dom.  Ten obiekt oferuje widoki na góry polozony w odleglosci spaceru od plazy i funkcje wysokiej klasy urzadzen kuchennych, ogród and sale ogromny bonus.', 'description_nl': 'Dit is een bungalow en is een droomhuis.  Deze eigenschap heeft uitzicht op de bergen gelegen op loopafstand van het strand en functies high-end keukenapparatuur, een tuin and een enorme bonus-kamer.', 'sqft': 648, 'daysOnMarket': 258, 'status': 'active', 'source': 'Aiden Paradis Homes', 'number': '15861', 'street': 'Southeast 16th Street', 'unit': None, 'type': 'House', 'city': 'Bellevue', 'region': 'wa', 'countryCode': 'us', 'postCode': '98008', 'location': {'type': 'Point', 'coordinates': [-122.127, 47.595], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 183384, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd1bt1home.jpg', 'tags': ['bungalow', 'dream home', 'mountain views', 'walking distance of beach', 'high end kitchen appliances', 'garden', 'huge bonus room'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': ['OTM4NjQzMg2'], 'language': 'en', 'translated_text': 'OTM4NjQzMg2', 'masked_text': '***********', 'pii_entities': [{'text': 'OTM4NjQzMg2', 'type': 'SWIFTCode', 'subtype': None, 'offset': 0, 'length': 11, 'score': 0.65}]}
# {'@search.score': 1.0, 'listingId': 'OTM4NjQzMw2', 'beds': 3, 'baths': 1, 'description': 'This is a condo and is well maintained.  Enjoy water frontage located close to parks and features viking appliances, a wall of windows and a guest house.', 'description_de': 'Dies ist eine Eigentumswohnung und ist sehr gepflegt.  Genießen Sie Wasser Fassade Parks in der Nähe und Funktionen Viking Geräte, eine Wand von windows and ein Gästehaus.', 'description_fr': 'Il s’agit d’un condo et est bien entretenu.  Profitez de façade de l’eau Situé à proximité de Parcs et appareils de caractéristiques de viking, un mur de fenêtres and une maison d’hôtes.', 'description_it': "Si tratta di un condominio ed è ben tenuto.  Godere di Riva d'acqua Situato vicino ai parchi e caratteristiche elettrodomestici viking, una parete di finestre and una guest house.", 'description_es': 'Se trata de un condominio y bien mantenido.  Disfrutar de frente de agua situado cerca de parques y electrodomésticos viking de características, una pared de ventanas and una casa de huéspedes.', 'description_pl': 'Jest to domek i jest dobrze utrzymany.  Ciesz sie wody pierzei usytuowany w poblizu parków i funkcje viking urzadzen, ciana and Pensjonat.', 'description_nl': 'Dit is een condo en is goed onderhouden.  Genieten van water voorgevel vlakbij parken en functies viking apparaten, een muur van windows and een pension.', 'sqft': 1944, 'daysOnMarket': 201, 'status': 'active', 'source': 'Leduc Homes', 'number': '20505', 'street': '7th Avenue Southwest', 'unit': '497', 'type': 'Apartment', 'city': 'Normandy Park', 'region': 'wa', 'countryCode': 'us', 'postCode': '98166', 'location': {'type': 'Point', 'coordinates': [-122.345, 47.4186], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 548208, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd3bt1apt.jpg', 'tags': ['condo', 'well maintained', 'water frontage', 'parks', 'viking appliances', 'wall of windows', 'guest house'], 'people': [], 'organizations': [], 'locations': ['OTM4NjQzMw2'], 'keyphrases': ['OTM4NjQzMw2'], 'language': 'en', 'translated_text': 'OTM4NjQzMw2', 'masked_text': 'OTM4NjQzMw2', 'pii_entities': []}
# {'@search.score': 1.0, 'listingId': 'OTM4NjQ0OQ2', 'beds': 3, 'baths': 1, 'description': 'This is a bachelor apartment and is perfect for entertaining.  This home provides a large lot located in a no through road and features a lap pool, crown mouldings and a wet bar.', 'description_de': 'Dies ist eine Bachelor-Wohnung und ist perfekt für Unterhaltung.  Dieses Haus bietet eine große Menge Das Hotel liegt in einer Sackgasse und verfügt über ein Sportbecken Krone Formteile and eine wet-bar.', 'description_fr': 'Il s’agit d’une Garçonnière et est parfait pour se divertir.  Cette maison offre un grand terrain situé dans un non par route et dispose d’une piscine, moulures and un wet-bar.', 'description_it': 'Si tratta di un appartamento di bachelor ed è perfetto per intrattenere.  Questa casa offre una grande partita Situato in un no attraverso strada e dispone di una piscina a corsie, modanature corona and un wet bar.', 'description_es': 'Este es un apartamento de soltero y es perfecto para el entretenimiento.  Esta casa ofrece un amplio Lote situado en un no a través de la carretera y cuenta con una piscina, moldeados de corona and una zona de bar.', 'description_pl': 'Jest to apartament licencjat i jest idealny do zabawy.  Ten dom zawiera wiele duzych polozony w nie poprzez drogi i dysponuje basenem, sztukaterie and barek.', 'description_nl': 'Dit is een Bachelor in appartement en is perfect voor entertaining.  Dit huis biedt een grote partij gelegen in een niet door weg en beschikt over een schoot zwembad, kroon lijstwerk and een natte bar.', 'sqft': 1944, 'daysOnMarket': 297, 'status': 'active', 'source': 'Tyler Poirier Homes', 'number': '22102', 'street': '109th Place Southeast', 'unit': '105', 'type': 'Apartment', 'city': 'Kent', 'region': 'wa', 'countryCode': 'us', 'postCode': '98031', 'location': {'type': 'Point', 'coordinates': [-122.196, 47.4039], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 458784, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd3bt1apt.jpg', 'tags': ['bachelor apartment', 'entertaining', 'large lot', 'no through road', 'lap pool', 'crown mouldings', 'wet bar'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': ['OTM4NjQ0OQ2'], 'language': 'en', 'translated_text': 'OTM4NjQ0OQ2', 'masked_text': '***********', 'pii_entities': [{'text': 'OTM4NjQ0OQ2', 'type': 'SWIFTCode', 'subtype': None, 'offset': 0, 'length': 11, 'score': 0.52}]}

# %% [markdown]
# ## Filter the result to only display the description in Spanish

# %%
params = {
    'api-version': api_version,
    '$top': 5
}
response = requests.get(url, headers=headers, params=params)
if response.status_code == 200:
    results = response.json()
    for document in results['value']:
      description_es = {
          'description_es': document.get('description_es')
      }
      print(description_es)
else:
    print(f"Error: {response.status_code}, {response.text}")
# Out:
# {'description_es': 'Este es un apartamento de soltero y es perfecto para el entretenimiento.  Esta propiedad tiene excelentes vistas situado en un culs-de-sac y características miele electrodomésticos, moldeados de corona and una sala adicional enorme.'}
# {'description_es': 'Se trata de un flatlet y está recién pintado.  Esta casa ofrece una superficie de la tierra situado en un callejón sin salida calle y cuenta con un den, un comedor formal and un porche cubierto.'}
# {'description_es': 'Se trata de un bungalow y es una casa de ensueño.  Esta propiedad tiene vistas a la montaña situado a poca distancia de una playa y electrodomésticos de alta gama de características, un jardín and una sala adicional enorme.'}
# {'description_es': 'Se trata de un condominio y bien mantenido.  Disfrutar de frente de agua situado cerca de parques y electrodomésticos viking de características, una pared de ventanas and una casa de huéspedes.'}
# {'description_es': 'Este es un apartamento de soltero y es perfecto para el entretenimiento.  Esta casa ofrece un amplio Lote situado en un no a través de la carretera y cuenta con una piscina, moldeados de corona and una zona de bar.'}

# %% [markdown]
# ## Apply a filter to the query itself to only return properties with 3 baths

# %%
params = {
    'api-version': api_version,
    '$filter': 'baths eq 3'
}
response = requests.get(url, headers=headers, params=params)
if response.status_code == 200:
    results = response.json()
    for document in results['value']:
        print(document)
else:
    print(f"Error: {response.status_code}, {response.text}")
# Out:
# {'@search.score': 1.0, 'listingId': 'OTM4NjQyOQ2', 'beds': 3, 'baths': 3, 'description': 'This is a bachelor apartment and is perfect for entertaining.  This property has great views located in a culs-de-sac and features miele appliances, crown mouldings and a huge bonus room.', 'description_de': 'Dies ist eine Bachelor-Wohnung und ist perfekt für Unterhaltung.  Dieses Hotel hat eine tolle Aussicht Das Hotel liegt in einer culs-de-sac und Funktionen Miele Geräte, Krone Formteile and ein riesiger Bonus-Zimmer.', 'description_fr': 'Il s’agit d’une Garçonnière et est parfait pour se divertir.  Cette propriété a une vue imprenable situé dans un culs-de-sac et caractéristiques miele appareils, moulures and un énorme bonus de chambre.', 'description_it': 'Si tratta di un appartamento di bachelor ed è perfetto per intrattenere.  Questa proprietà ha una vista fantastica Situato in un culs-de-sac ed elettrodomestici miele caratteristiche, modanature corona and una stanza enorme bonus.', 'description_es': 'Este es un apartamento de soltero y es perfecto para el entretenimiento.  Esta propiedad tiene excelentes vistas situado en un culs-de-sac y características miele electrodomésticos, moldeados de corona and una sala adicional enorme.', 'description_pl': 'Jest to apartament licencjat i jest idealny do zabawy.  Ten obiekt oferuje wspaniale widoki na znajduje sie w culs-de-sac i funkcje urzadzen miele, sztukaterie and sale ogromny bonus.', 'description_nl': 'Dit is een Bachelor in appartement en is perfect voor entertaining.  Deze eigenschap heeft een fantastisch uitzicht gelegen in een culs-de-sac en functies miele apparaten, kroon lijstwerk and een enorme bonus-kamer.', 'sqft': 5832, 'daysOnMarket': 249, 'status': 'active', 'source': 'Lucas Roberts Homes', 'number': '451', 'street': '150th Place Northeast', 'unit': '637', 'type': 'Apartment', 'city': 'Bellevue', 'region': 'wa', 'countryCode': 'us', 'postCode': '98007', 'location': {'type': 'Point', 'coordinates': [-122.137, 47.614], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 1650456, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd3bt3apt.jpg', 'tags': ['bachelor apartment', 'entertaining', 'great views', 'culs-de-sac', 'miele appliances', 'crown mouldings', 'huge bonus room'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': ['OTM4NjQyOQ2'], 'language': 'en', 'translated_text': 'OTM4NjQyOQ2', 'masked_text': 'OTM4NjQyOQ2', 'pii_entities': []}
# {'@search.score': 1.0, 'listingId': 'OTM4NjE3Ng2', 'beds': 4, 'baths': 3, 'description': 'This is a condo and is brand new.  Enjoy gleaming hardwood floors located on a no outlet and features an attached garage, french doors throughout and a large laundry room.', 'description_de': 'Dies ist eine Eigentumswohnung und ist die Marke neu.  Genießen Sie glänzenden Holzböden Das Hotel liegt auf einem keine Steckdose und verfügt über eine angebaute Garage Französisch Türen im gesamten and eine große Waschküche.', 'description_fr': 'Il s’agit d’un condo et est la marque nouvelle.  Profitez de parquet brillant Situé sur une aucune prise et dispose d’un garage attenant, français les portes tout au long de and une grande buanderie.', 'description_it': 'Si tratta di un condominio ed è il marchio nuovo.  Godere di luccicanti pavimenti Situato su una non presa e dispone di un garage collegato, porte-finestre in tutto and una grande sala lavanderia.', 'description_es': 'Se trata de un condominio y es marca nueva.  Disfrutar relucientes pisos de madera situado en una sin salida y cuenta con un garaje adjunto, francés puertas a lo largo de and un amplio lavadero.', 'description_pl': 'Jest to domek i to nowa marka.  Ciesz sie lsniace drewniane podlogi znajduje sie na nie gniazda i posiada garaz, Francuskie drzwi calym and duzy pralnia.', 'description_nl': 'Dit is een condo en is het merk nieuwe.  Geniet van de glanzende hardhoutvloeren gelegen op een geen stopcontact en beschikt over een aangebouwde garage, tuindeuren in de gehele and een grote wasruimte.', 'sqft': 7776, 'daysOnMarket': 207, 'status': 'active', 'source': 'Houle Homes', 'number': '11514', 'street': 'Southeast 221st Place', 'unit': '532', 'type': 'Apartment', 'city': 'Kent', 'region': 'wa', 'countryCode': 'us', 'postCode': '98031', 'location': {'type': 'Point', 'coordinates': [-122.188, 47.4039], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 1555200, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd4bt3apt.jpg', 'tags': ['condo', 'brand new', 'hardwood floors', 'no outlet', 'attached garage', 'french doors throughout', 'large laundry room'], 'people': [], 'organizations': [], 'locations': ['4Nj'], 'keyphrases': [], 'language': 'sq', 'translated_text': 'OTM4NjE3Ng2', 'masked_text': 'OTM4NjE3Ng2', 'pii_entities': []}
# {'@search.score': 1.0, 'listingId': 'OTM4NjE5Mw2', 'beds': 3, 'baths': 3, 'description': 'This is a flatlet and is a beautiful home.  This home provides an acreage of land located in a no through road and features a den, a generous backyard and two master suites.', 'description_de': 'Dies ist ein Allergiker und ist ein schönes Zuhause.  Dieses Haus bietet eine Anbaufläche von land Das Hotel liegt in einer Sackgasse und verfügt über eine Höhle, ein großzügiger Garten and zwei master-Suiten.', 'description_fr': 'Il s’agit d’un appartement et est une belle maison.  Cette maison offre une superficie de terrain situé dans un non par route et dispose d’un boudoir, un jardin généreux and deux suites master.', 'description_it': 'Si tratta di una casetta è una bellissima casa.  Questa casa offre una superficie di terra Situato in un no attraverso strada e dispone di una tana, un generoso cortile and due master suite.', 'description_es': 'Se trata de un flatlet y es una hermosa casa.  Esta casa ofrece una superficie de la tierra situado en un no a través de la carretera y cuenta con un den, un generoso patio trasero and dos Masters suites.', 'description_pl': 'Jest to mieszkanie i jest piekny dom.  Ten dom zapewnia areal ziemi polozony w nie poprzez drogi funkcje w den i hojny podwórku and dwa apartamenty.', 'description_nl': 'Dit is een flatlet en is een mooi huis.  Dit huis biedt een areaal van land gelegen in een niet door weg en is voorzien van een den, een royale achtertuin and twee master suites.', 'sqft': 5832, 'daysOnMarket': 240, 'status': 'active', 'source': 'Tyler Boivin Realty', 'number': '21658', 'street': 'Southeast 239th Place', 'unit': '63', 'type': 'Apartment', 'city': 'Maple Valley', 'region': 'wa', 'countryCode': 'us', 'postCode': '98038', 'location': {'type': 'Point', 'coordinates': [-122.051, 47.3875], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 1189728, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd3bt3apt.jpg', 'tags': ['flatlet', 'beautiful home', 'acreage of land', 'no through road', 'den', 'generous backyard', 'two master suites'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': [], 'language': 'sq', 'translated_text': 'OTM4NjE5Mw2', 'masked_text': 'OTM4NjE5Mw2', 'pii_entities': []}
# {'@search.score': 1.0, 'listingId': 'OTM4NjM1Ng2', 'beds': 4, 'baths': 3, 'description': 'This is a bachelor apartment and is perfect for entertaining.  This property has great views located in a cul-de-sac and features viking appliances, beautiful bedroom floors and two master suites.', 'description_de': 'Dies ist eine Bachelor-Wohnung und ist perfekt für Unterhaltung.  Dieses Hotel hat eine tolle Aussicht gelegen in einer Sackgasse und Funktionen Viking Geräte, schöne Zimmer-Etagen and zwei master-Suiten.', 'description_fr': 'Il s’agit d’une Garçonnière et est parfait pour se divertir.  Cette propriété a une vue imprenable situé dans une impasse et appareils de caractéristiques de viking, planchers de belle chambre and deux suites master.', 'description_it': 'Si tratta di un appartamento di bachelor ed è perfetto per intrattenere.  Questa proprietà ha una vista fantastica Situato in una strada senza uscita e caratteristiche elettrodomestici viking, piani di bella camera da letto and due master suite.', 'description_es': 'Este es un apartamento de soltero y es perfecto para el entretenimiento.  Esta propiedad tiene excelentes vistas situado en un callejón sin salida y electrodomésticos viking de características, pisos de dormitorio hermoso and dos Masters suites.', 'description_pl': 'Jest to apartament licencjat i jest idealny do zabawy.  Ten obiekt oferuje wspaniale widoki na polozony w zaulku i funkcje viking urzadzen, piekna sypialnia podlogi and dwa apartamenty.', 'description_nl': 'Dit is een Bachelor in appartement en is perfect voor entertaining.  Deze eigenschap heeft een fantastisch uitzicht gelegen in een doodlopende straat en functies viking apparaten, mooie slaapkamer vloeren and twee master suites.', 'sqft': 7776, 'daysOnMarket': 90, 'status': 'sold', 'source': 'Aiden Harris Realtors', 'number': '16317', 'street': 'Southeast 40th Street', 'unit': '413', 'type': 'Apartment', 'city': 'Bellevue', 'region': 'wa', 'countryCode': 'us', 'postCode': '98006', 'location': {'type': 'Point', 'coordinates': [-122.124, 47.5738], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 1780704, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd4bt3apt.jpg', 'tags': ['bachelor apartment', 'entertaining', 'great views', 'cul-de-sac', 'viking appliances', 'beautiful bedroom floors', 'two master suites'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': ['OTM4NjM1Ng2'], 'language': 'en', 'translated_text': 'OTM4NjM1Ng2', 'masked_text': '***********', 'pii_entities': [{'text': 'OTM4NjM1Ng2', 'type': 'SWIFTCode', 'subtype': None, 'offset': 0, 'length': 11, 'score': 0.99}]}
# {'@search.score': 1.0, 'listingId': 'OTM4NjUyMg2', 'beds': 4, 'baths': 3, 'description': 'This is a semi-detached house and is brand new.  This property has mountain views located in a cul-de-sac and features a home office, a garden and a covered front porch.', 'description_de': 'Dies ist eine Doppelhaushälfte und ist die Marke neu.  Diese Eigenschaft hat Aussicht auf die Berge gelegen in einer Sackgasse und verfügt über ein home-Office einen Garten and eine überdachte Veranda.', 'description_fr': 'Il s’agit d’une maison jumelée et est la marque nouvelle.  Cette propriété n’a vue sur la montagne situé dans une impasse et dispose d’un bureau à domicile, un jardin and une véranda couverte.', 'description_it': 'Si tratta di una casa bifamiliare ed è il marchio nuovo.  Questa proprietà ha la vista sulle montagne Situato in una strada senza uscita e dispone di un ufficio a casa, un giardino and un portico anteriore coperto.', 'description_es': 'Esta es una casa adosada y es marca nueva.  Esta propiedad tiene vistas a la montaña situado en un callejón sin salida y cuenta con una oficina en casa, un jardín and un porche cubierto.', 'description_pl': 'Jest to dom-blizniak i to nowa marka.  Ten obiekt oferuje widoki na góry polozony w zaulku i posiada biuro w domu, ogród and weranda przednie.', 'description_nl': 'Dit is een semi-vrijstaande woning en is het merk nieuwe.  Deze eigenschap heeft uitzicht op de bergen gelegen in een doodlopende straat en beschikt over een kantoor aan huis, een tuin and een overdekte veranda.', 'sqft': 7776, 'daysOnMarket': 204, 'status': 'pending', 'source': 'Eric Sanchez Realtors', 'number': '17434', 'street': '145th Place Northeast', 'unit': None, 'type': 'House', 'city': 'Woodinville', 'region': 'wa', 'countryCode': 'us', 'postCode': '98072', 'location': {'type': 'Point', 'coordinates': [-122.146, 47.7548], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 1796256, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd4bt3home.jpg', 'tags': ['semi-detached house', 'brand new', 'mountain views', 'cul-de-sac', 'home office', 'garden', 'covered front porch'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': ['OTM4NjUyMg2'], 'language': 'en', 'translated_text': 'OTM4NjUyMg2', 'masked_text': '***********', 'pii_entities': [{'text': 'OTM4NjUyMg2', 'type': 'SWIFTCode', 'subtype': None, 'offset': 0, 'length': 11, 'score': 0.98}]}
# {'@search.score': 1.0, 'listingId': 'OTM4NjU0Mg2', 'beds': 4, 'baths': 3, 'description': 'This is a condominium and is priced to sell.  Enjoy water frontage located in a no through road and features an office, a generous backyard and a covered front porch.', 'description_de': 'Dies ist eine Eigentumswohnung und ist preislich um zu verkaufen.  Genießen Sie Wasser Fassade Das Hotel liegt in einer Sackgasse und ist mit einem Büro, ein großzügiger Garten and eine überdachte Veranda.', 'description_fr': 'Il s’agit d’un immeuble en copropriété un prix pour vendre.  Profitez de façade de l’eau situé dans un non par route et un bureau, un jardin généreux and une véranda couverte.', 'description_it': "Si tratta di un condominio ed è un prezzo di vendita.  Godere di Riva d'acqua Situato in un no attraverso strada e dispone di un ufficio, un generoso cortile and un portico anteriore coperto.", 'description_es': 'Se trata de un condominio y tiene un precio para vender.  Disfrutar de frente de agua situado en un no a través de la carretera y características de una oficina, un generoso patio trasero and un porche cubierto.', 'description_pl': 'Jest to kondominium i jest w cenie sprzedazy.  Ciesz sie wody pierzei polozony w nie poprzez drogi i funkcje Biuro, hojny podwórku and weranda przednie.', 'description_nl': 'Dit is een condominium zijn en wordt geprijst om te verkopen.  Genieten van water voorgevel gelegen in een niet door weg en beschikt over een bureau, een royale achtertuin and een overdekte veranda.', 'sqft': 7776, 'daysOnMarket': 90, 'status': 'active', 'source': 'Robinson Realty', 'number': '12339', 'street': 'Southeast 23rd Place', 'unit': '42', 'type': 'Apartment', 'city': 'Bellevue', 'region': 'wa', 'countryCode': 'us', 'postCode': '98005', 'location': {'type': 'Point', 'coordinates': [-122.172, 47.5894], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 2107296, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd4bt3apt.jpg', 'tags': ['condominium', 'priced to sell', 'water frontage', 'no through road', 'office', 'generous backyard', 'covered front porch'], 'people': [], 'organizations': [], 'locations': ['OTM4Nj', '0Mg'], 'keyphrases': [], 'language': 'hr', 'translated_text': 'OTM4NJU0Mg2', 'masked_text': 'OTM4NjU0Mg2', 'pii_entities': []}
# {'@search.score': 1.0, 'listingId': 'OTM4NjI4OA2', 'beds': 3, 'baths': 3, 'description': 'This is a multi-story residence and is a beautiful home.  Enjoy water frontage located close to schools and features a lap pool, a generous backyard and two master suites.', 'description_de': 'Dies ist ein mehrstöckiges Wohnhaus und ist ein schönes Zuhause.  Genießen Sie Wasser Fassade Das Hotel liegt in der Nähe von Schulen und verfügt über ein Sportbecken ein großzügiger Garten and zwei master-Suiten.', 'description_fr': 'Il s’agit d’une résidence de plusieurs étages et est une belle maison.  Profitez de façade de l’eau Situé à proximité des écoles et dispose d’une piscine, un jardin généreux and deux suites master.', 'description_it': "Si tratta di un residence di multi-storia è una bellissima casa.  Godere di Riva d'acqua Situato vicino alle scuole e dispone di una piscina a corsie, un generoso cortile and due master suite.", 'description_es': 'Se trata de una residencia de varios pisos y es una hermosa casa.  Disfrutar de frente de agua situado cerca de colegios y cuenta con una piscina, un generoso patio trasero and dos Masters suites.', 'description_pl': 'Jest to historia wielu pobytu i jest piekny dom.  Ciesz sie wody pierzei polozony w poblizu szkoly i dysponuje basenem, hojny podwórku and dwa apartamenty.', 'description_nl': 'Dit is een multi verhaal residentie en is een mooi huis.  Genieten van water voorgevel vlakbij scholen en beschikt over een schoot zwembad, een royale achtertuin and twee master suites.', 'sqft': 5832, 'daysOnMarket': 102, 'status': 'active', 'source': 'Berube Realty', 'number': '15005', 'street': '37th Avenue Northeast', 'unit': None, 'type': 'House', 'city': 'Lake Forest Park', 'region': 'wa', 'countryCode': 'us', 'postCode': '98155', 'location': {'type': 'Point', 'coordinates': [-122.289, 47.7372], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 1178064, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd3bt3home.jpg', 'tags': ['multi-story residence', 'beautiful home', 'water frontage', 'schools', 'lap pool', 'generous backyard', 'two master suites'], 'people': [], 'organizations': [], 'locations': [], 'keyphrases': ['OTM4NjI4OA2'], 'language': 'en', 'translated_text': 'OTM4NjI4OA2', 'masked_text': '***********', 'pii_entities': [{'text': 'OTM4NjI4OA2', 'type': 'SWIFTCode', 'subtype': None, 'offset': 0, 'length': 11, 'score': 0.99}]}
# {'@search.score': 1.0, 'listingId': 'OTM4NjIwNg2', 'beds': 3, 'baths': 3, 'description': 'This is a semi-detached house and is a dream home.  Enjoy lake front property located close to shopping and features a den, wood floors and a guest room.', 'description_de': 'Dies ist eine Doppelhaushälfte und ist ein Traumhaus.  Genießen Sie See Immobilien Das Hotel liegt nahe an den Geschäften und verfügt über eine Höhle, Holzböden and ein Gästezimmer.', 'description_fr': 'Il s’agit d’une maison jumelée et est une maison de rêve.  Profitez de cette propriété front de lac Situé à proximité des commerces et dispose d’un boudoir, planchers de bois and une chambre d’hôtes.', 'description_it': 'Si tratta di una casa bifamiliare ed è una casa da sogno.  Godere di proprietà fronte lago Situato vicino a negozi e dispone di una tana, pavimenti in legno and Camera per gli ospiti.', 'description_es': 'Esta es una casa adosada y es una casa de ensueño.  Disfrute de propiedad frente lago situado cerca de tiendas y cuenta con un den, pisos de madera and una habitación de huéspedes.', 'description_pl': 'Jest to dom-blizniak i jest wymarzony dom.  Ciesz sie lake front Wlasciwosc polozony w poblizu zakupy funkcje w den i podlogi drewniane and Pokój goscinny.', 'description_nl': 'Dit is een semi-vrijstaande woning en is een droomhuis.  Geniet van lake eigendom vlakbij winkels en is voorzien van een den, houten vloeren and een kamer.', 'sqft': 5832, 'daysOnMarket': 111, 'status': 'active', 'source': 'Angel Morris Realtors', 'number': '23953', 'street': '58th Court South', 'unit': None, 'type': 'House', 'city': 'Kent', 'region': 'wa', 'countryCode': 'us', 'postCode': '98032', 'location': {'type': 'Point', 'coordinates': [-122.261, 47.3874], 'crs': {'type': 'name', 'properties': {'name': 'EPSG:4326'}}}, 'price': 1533816, 'thumbnail': 'https://searchdatasets.blob.core.windows.net/images/bd3bt3home.jpg', 'tags': ['semi-detached house', 'dream home', 'lake front property', 'shopping', 'den', 'wood floors', 'guest room'], 'people': [], 'organizations': [], 'locations': ['OTM4NjIwNg2'], 'keyphrases': ['OTM4NjIwNg2'], 'language': 'en', 'translated_text': 'OTM4NjIwNg2', 'masked_text': '***********', 'pii_entities': [{'text': 'OTM4NjIwNg2', 'type': 'SWIFTCode', 'subtype': None, 'offset': 0, 'length': 11, 'score': 0.99}]}
